# %%
import pandas as pd
import numpy as np

# %%
skuinfo = pd.read_csv('skuinfo.csv', header = None, sep = ',', dtype = 'str', 
                      names = ['SKU', 'DEPT','CLASSID','UPC','STYLE','COLOR','SIZE','PACKSIZE','VENDOR','BRAND','UNKNOWN1','UNKNOWN2','UNKNOWN3'])

# %%
skuinfo
# Out:
#              SKU  DEPT CLASSID              UPC         STYLE         COLOR  \
# 0              3  6505     113  000400000003000  00    F55KT2  WHISPERWHITE
# 1              4  8101     002  000400000004000  22    615CZ4  SPEARMI
# 2              5  7307     003  000400000005000  7LBS  245-01  34 SILVER
# 3              8  3404     00B  000400000008000  622   F05H84  MORNING MI
# 4             15  2301     004  000400000015000  126   MDU461  255CAMEL
# ...          ...   ...     ...              ...           ...           ...
# 1564173  9999973  3103     009  000400009973999  702   S3JAYV  STONE
# 1564174  9999974  9801     726  000400009974999        G50171  NAVY MULTI
# 1564175  9999991  2301     004  000400009991999  026   MDU201  618RED ROSE
# 1564176  9999992  1202     402  000400009992999  14    F52UN1  PALE JADE
# 1564177  9999997  2503     111  000400009997999  1     1XKBGO  210CHOPNK
#
#                SIZE PACKSIZE   VENDOR      BRAND UNKNOWN1 UNKNOWN2 UNKNOWN3
# ...

# %%
skuinfo.drop(['UNKNOWN1','UNKNOWN2','UNKNOWN3'],axis=1,inplace=True)

# %%
skuinfo
# Out:
#              SKU  DEPT CLASSID              UPC         STYLE         COLOR  \
# 0              3  6505     113  000400000003000  00    F55KT2  WHISPERWHITE
# 1              4  8101     002  000400000004000  22    615CZ4  SPEARMI
# 2              5  7307     003  000400000005000  7LBS  245-01  34 SILVER
# 3              8  3404     00B  000400000008000  622   F05H84  MORNING MI
# 4             15  2301     004  000400000015000  126   MDU461  255CAMEL
# ...          ...   ...     ...              ...           ...           ...
# 1564173  9999973  3103     009  000400009973999  702   S3JAYV  STONE
# 1564174  9999974  9801     726  000400009974999        G50171  NAVY MULTI
# 1564175  9999991  2301     004  000400009991999  026   MDU201  618RED ROSE
# 1564176  9999992  1202     402  000400009992999  14    F52UN1  PALE JADE
# 1564177  9999997  2503     111  000400009997999  1     1XKBGO  210CHOPNK
#
#                SIZE PACKSIZE   VENDOR      BRAND
# ...

# %%
skuinfo['SIZE'] = skuinfo['SIZE'].str.strip()

# skuinfo['SIZE'] = skuinfo['SIZE'].apply(lambda x: None if x == 'NOSIZE' else x)
# skuinfo['SIZE'] = skuinfo['SIZE'].apply(lambda x: None if x == 'NO SIZE' else x)

# skuinfo['SIZE'] = skuinfo['SIZE'].apply(lambda x: None if x == '' else x)
# skuinfo['SIZE'] = skuinfo['SIZE'].apply(lambda x: None if x == 'NA' else x)

# %%
skuinfo['SIZE'] = skuinfo['SIZE'].str.strip()

#skuinfo[skuinfo['SIZE']==None]

# %%
valuecount=skuinfo['SIZE'].value_counts()

# %%
count_df = pd.DataFrame({'Category': valuecount.index, 'Count': valuecount.values})
count_df.iloc[50:70]
# Out:
#    Category  Count
# 50     P064   4553
# 51       22   4212
# 52     105M   4011
# 53      XLT   3920
# 54       4X   3910
# 55      2XT   3888
# 56      3XT   3783
# 57      18W   3537
# 58  NO SIZE   3432
# 59      22W   3427
# 60      20W   3420
# 61      16W   3354
# 62       28   3261
# 63      24W   3205
# 64      4XT   3173
# 65       29   3081
# 66       31   3030
# 67       34   3014
# 68       36   2981
# 69        P   2957

# %%
skuinfo[skuinfo['SIZE']=='NO SIZE']
# Out:
#              SKU  DEPT CLASSID              UPC         STYLE         COLOR  \
# 99           425  2200     009  000400000425000        0771    00-S'03
# 100          426  2200     009  000400000426000        0768    02-VIOLET
# 136          604  4402     401  000400000604000        74648   TURQ
# 234         1125  4402     201  000400001125000        93560   SILVER
# 1181        8060  8000     006  000400008060000  3     110923  CORP GWP
# ...          ...   ...     ...              ...           ...           ...
# 1562739  9990425  2200     009  000400000425999        0768    01-NOIR MA
# 1562867  9991124  4402     101  000400001124999        93559   GOLD
# 1562995  9991712  7200     007  000400001712999  150   FP3281  DAZZLING DUO
# 1563559  9996713  2200     009  000400006713999        8994    39-METALLI
# 1564114  9999764  4402     403  000400009764999        65419   NATURAL
#
#             SIZE PACKSIZE   VENDOR      BRAND
# 99       NO SIZE        1  0113645  LANCOME
# ...

# %%
skuinfo = skuinfo[~skuinfo['SIZE'].isin(['NOSIZE', 'NO SIZE'])]
skuinfo
# Out:
#              SKU  DEPT CLASSID              UPC         STYLE         COLOR  \
# 0              3  6505     113  000400000003000  00    F55KT2  WHISPERWHITE
# 1              4  8101     002  000400000004000  22    615CZ4  SPEARMI
# 2              5  7307     003  000400000005000  7LBS  245-01  34 SILVER
# 3              8  3404     00B  000400000008000  622   F05H84  MORNING MI
# 4             15  2301     004  000400000015000  126   MDU461  255CAMEL
# ...          ...   ...     ...              ...           ...           ...
# 1564173  9999973  3103     009  000400009973999  702   S3JAYV  STONE
# 1564174  9999974  9801     726  000400009974999        G50171  NAVY MULTI
# 1564175  9999991  2301     004  000400009991999  026   MDU201  618RED ROSE
# 1564176  9999992  1202     402  000400009992999  14    F52UN1  PALE JADE
# 1564177  9999997  2503     111  000400009997999  1     1XKBGO  210CHOPNK
#
#          SIZE PACKSIZE   VENDOR      BRAND
# 0        P8EA        1  5119207  TURNBURY
# ...

# %%
# na_variations = ['n/a', 'na', 'not applicable', 'none', 'n.a', 'n.a.', 'n.a..', 'naa', 'naaa', 'n/a?', 'n/a!', 'N/A']

# skuinfo[skuinfo['SIZE'].isin(na_variations)]

# %%
# skuinfo['SIZE'] = skuinfo['SIZE'].apply(lambda x: 'NA' if x == 'NO SIZE' else x)
# skuinfo['SIZE'] = skuinfo['SIZE'].apply(lambda x: 'NA' if x == '' else x)

# %%
# skuinfo[skuinfo.isna().any(axis=1)]

# %%
na_variations = ['n/a', 'na', 'not applicable', 'none', 'n.a', 'n.a.', 'n.a..', 'naa', 'naaa', 'n/a?', 'n/a!', 'N/A']
skuinfo['STYLE'] = skuinfo['STYLE'].astype(str)
skuinfo['STYLE'] = skuinfo['STYLE'].str.lower()

# Replace all 'na' variations with 'na' (case-insensitive)
skuinfo['STYLE'].replace(na_variations, 'na', regex=True, inplace=True)

# Convert 'na' back to uppercase in the original column
skuinfo['STYLE'] = skuinfo['STYLE'].str.upper()
skuinfo['STYLE'] = skuinfo['STYLE'].apply(lambda x: None if x.lower() == 'na' else x)
skuinfo['STYLE'] = skuinfo['STYLE'].apply(lambda x: None if x == '' else x)
# Out:
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/3580239465.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['STYLE'] = skuinfo['STYLE'].astype(str)
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/3580239465.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['STYLE'] = skuinfo['STYLE'].str.lower()
# /Users/judyzhu/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# ...

# %%
skuinfo['SIZE'].isnull().sum()
# Out:
# 0

# %%
skuinfo[skuinfo['SIZE']==' ']
# Out:
# Empty DataFrame
# Columns: [SKU, DEPT, CLASSID, UPC, STYLE, COLOR, SIZE, PACKSIZE, VENDOR, BRAND]
# Index: []

# %%
#,'STYLE','SIZE'

# %%
# Replace 'N/A' with None (case-insensitive)
# skuinfo['COLOR'] = skuinfo['COLOR'].astype(str)
# skuinfo['COLOR'] = skuinfo['COLOR'].str.replace('N/A', '').str.strip()
# skuinfo['COLOR'] = skuinfo['COLOR'].apply(lambda x: None if x.lower() == 'na' else x)
# skuinfo['COLOR'] = skuinfo['COLOR'].apply(lambda x: None if x == '' else x)

# %%
na_variations = ['n/a', 'na', 'not applicable', 'none', 'n.a', 'n.a.', 'n.a..', 'naa', 'naaa', 'n/a?', 'n/a!', 'N/A']
skuinfo['COLOR'] = skuinfo['COLOR'].astype(str)
skuinfo['COLOR'] = skuinfo['COLOR'].str.lower()

# Replace all 'na' variations with 'na' (case-insensitive)
skuinfo['COLOR'].replace(na_variations, 'na', regex=True, inplace=True)

# Convert 'na' back to uppercase in the original column
skuinfo['COLOR'] = skuinfo['COLOR'].str.upper()
skuinfo['COLOR'] = skuinfo['COLOR'].apply(lambda x: None if x.lower() == 'na' else x)
skuinfo['COLOR'] = skuinfo['COLOR'].apply(lambda x: None if x == '' else x)
# Out:
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/171393974.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['COLOR'] = skuinfo['COLOR'].astype(str)
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/171393974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['COLOR'] = skuinfo['COLOR'].str.lower()
# /Users/judyzhu/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# ...

# %%
skuinfo[skuinfo.isna().any(axis=1)]
#mask = df.apply(lambda row: row.astype(str).str.contains(search_string, case=False).any(), axis=1)
skuinfo.dropna()
# Out:
#              SKU  DEPT CLASSID              UPC         STYLE         COLOR  \
# 0              3  6505     113  000400000003000  00    F55KT2  WHISPERWHITE
# 1              4  8101     002  000400000004000  22    615CZ4  SPEARMI
# 2              5  7307     003  000400000005000  7LBS  245-01  34 SILVER
# 3              8  3404     00B  000400000008000  622   F05H84  MORNING MI
# 4             15  2301     004  000400000015000  126   MDU461  255CAMEL
# ...          ...   ...     ...              ...           ...           ...
# 1564173  9999973  3103     009  000400009973999  702   S3JAYV  STONE
# 1564174  9999974  9801     726  000400009974999        G50171  NAVY MULTI
# 1564175  9999991  2301     004  000400009991999  026   MDU201  618RED ROSE
# 1564176  9999992  1202     402  000400009992999  14    F52UN1  PALE JADE
# 1564177  9999997  2503     111  000400009997999  1     1XKBGO  210CHOPNK
#
#          SIZE PACKSIZE   VENDOR      BRAND
# 0        P8EA        1  5119207  TURNBURY
# ...

# %%
#skuinfo['PACKSIZE'].astype(int)

# %%
na_variations = ['n/a', 'na', 'not applicable', 'none', 'n.a', 'n.a.', 'n.a..', 'naa', 'naaa', 'n/a?', 'n/a!', 'N/A']
skuinfo['SKU'] = skuinfo['SKU'].str.lower()

# Replace all 'na' variations with 'na' (case-insensitive)
skuinfo['SKU'].replace(na_variations, 'na', regex=True, inplace=True)

# Convert 'na' back to uppercase in the original column
skuinfo['SKU'] = skuinfo['SKU'].str.upper()
skuinfo['SKU'] = skuinfo['SKU'].apply(lambda x: None if x.lower() == 'na' else x)
skuinfo['SKU'] = skuinfo['SKU'].apply(lambda x: None if x == '' else x)
# Out:
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/370390216.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['SKU'] = skuinfo['SKU'].str.lower()
# /Users/judyzhu/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/370390216.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
skuinfo['DEPT'] = skuinfo['DEPT'].str.lower()

# Replace all 'na' variations with 'na' (case-insensitive)
skuinfo['DEPT'].replace(na_variations, 'na', regex=True, inplace=True)

# Convert 'na' back to uppercase in the original column
skuinfo['DEPT'] = skuinfo['DEPT'].str.upper()
skuinfo['DEPT'] = skuinfo['DEPT'].apply(lambda x: None if x.lower() == 'na' else x)
skuinfo['DEPT'] = skuinfo['DEPT'].apply(lambda x: None if x == '' else x)
# Out:
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/621896734.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['DEPT'] = skuinfo['DEPT'].str.lower()
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/621896734.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['DEPT'] = skuinfo['DEPT'].str.upper()
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/621896734.py:8: SettingWithCopyWarning:
# ...

# %%
skuinfo['CLASSID'] = skuinfo['CLASSID'].str.lower()

# Replace all 'na' variations with 'na' (case-insensitive)
skuinfo['CLASSID'].replace(na_variations, 'na', regex=True, inplace=True)

# Convert 'na' back to uppercase in the original column
skuinfo['CLASSID'] = skuinfo['CLASSID'].str.upper()
skuinfo['CLASSID'] = skuinfo['CLASSID'].apply(lambda x: None if x.lower() == 'na' else x)
skuinfo['CLASSID'] = skuinfo['CLASSID'].apply(lambda x: None if x == '' else x)
# Out:
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/2455299924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['CLASSID'] = skuinfo['CLASSID'].str.lower()
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/2455299924.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['CLASSID'] = skuinfo['CLASSID'].str.upper()
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/2455299924.py:8: SettingWithCopyWarning:
# ...

# %%
skuinfo['UPC'] = skuinfo['UPC'].str.lower()

# Replace all 'na' variations with 'na' (case-insensitive)
skuinfo['UPC'].replace(na_variations, 'na', regex=True, inplace=True)

# Convert 'na' back to uppercase in the original column
skuinfo['UPC'] = skuinfo['UPC'].str.upper()
skuinfo['UPC'] = skuinfo['UPC'].apply(lambda x: None if x.lower() == 'na' else x)
skuinfo['UPC'] = skuinfo['UPC'].apply(lambda x: None if x == '' else x)
# Out:
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/473284889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['UPC'] = skuinfo['UPC'].str.lower()
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/473284889.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['UPC'] = skuinfo['UPC'].str.upper()
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/473284889.py:8: SettingWithCopyWarning:
# ...

# %%
skuinfo['PACKSIZE']=skuinfo['PACKSIZE'].astype(str)
skuinfo['PACKSIZE'] = skuinfo['PACKSIZE'].str.replace('ONE', '1').str.strip()

skuinfo['PACKSIZE'] = skuinfo['PACKSIZE'].str.lower()

# Replace all 'na' variations with 'na' (case-insensitive)
skuinfo['PACKSIZE'].replace(na_variations, 'na', regex=True, inplace=True)

# Convert 'na' back to uppercase in the original column
skuinfo['PACKSIZE'] = skuinfo['PACKSIZE'].str.upper()
skuinfo['PACKSIZE'] = skuinfo['PACKSIZE'].apply(lambda x: None if x.lower() == 'na' else x)
skuinfo['PACKSIZE'] = skuinfo['PACKSIZE'].apply(lambda x: None if x == '' else x)
# Out:
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/2045234136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['PACKSIZE']=skuinfo['PACKSIZE'].astype(str)
# /var/folders/3l/jn4gt4rs4mg4gw9b4dzw4t7h0000gn/T/ipykernel_71792/2045234136.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skuinfo['PACKSIZE'] = skuinfo['PACKSIZE'].str.replace('ONE', '1').str.strip()
# ...

# %%
#drop all na
skuinfo.dropna(inplace=True)
# Out:
# /Users/judyzhu/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
skuinfo[skuinfo.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [SKU, DEPT, CLASSID, UPC, STYLE, COLOR, SIZE, PACKSIZE, VENDOR, BRAND]
# Index: []

# %%
skuinfo = skuinfo[skuinfo['PACKSIZE'].str.match(r'^\d+$')]
skuinfo = skuinfo[skuinfo['CLASSID'].str.match(r'^[0-9]+$')]
skuinfo
# Out:
#              SKU  DEPT CLASSID              UPC         STYLE         COLOR  \
# 0              3  6505     113  000400000003000  00    F55KT2  WHISPERWHITE
# 1              4  8101     002  000400000004000  22    615CZ4  SPEARMI
# 2              5  7307     003  000400000005000  7LBS  245-01  34 SILVER
# 4             15  2301     004  000400000015000  126   MDU461  255CAMEL
# 5             20  6006     711  000400000020000        669N26  NEWPORT NA
# ...          ...   ...     ...              ...           ...           ...
# 1564173  9999973  3103     009  000400009973999  702   S3JAYV  STONE
# 1564174  9999974  9801     726  000400009974999        G50171  NAVY MULTI
# 1564175  9999991  2301     004  000400009991999  026   MDU201  618RED ROSE
# 1564176  9999992  1202     402  000400009992999  14    F52UN1  PALE JADE
# 1564177  9999997  2503     111  000400009997999  1     1XKBGO  210CHOPNK
#
#          SIZE PACKSIZE   VENDOR      BRAND
# 0        P8EA        1  5119207  TURNBURY
# ...

# %%
skuinfo['COLOR'].str.strip().unique()
# Out:
# array(['WHISPERWHITE', 'SPEARMI', '34 SILVER', ..., 'LR078-280',
#        '01171020', '10BERRY'], dtype=object)

# %%
skuinfo['SKU']=skuinfo['SKU'].astype(int)
skuinfo['DEPT']=skuinfo['DEPT'].astype(int)
skuinfo['PACKSIZE']=skuinfo['PACKSIZE'].astype(int)

# %%
skuinfo[skuinfo['SKU'].isna()]
# Out:
# Empty DataFrame
# Columns: [SKU, DEPT, CLASSID, UPC, STYLE, COLOR, SIZE, PACKSIZE, VENDOR, BRAND]
# Index: []

# %%
file_path = 'cleansku.csv'  # Replace with your desired file path

# Save the DataFrame to a CSV file
skuinfo.to_csv(file_path, index=False)  #

# %%
# skuinfo

# %%
# skuinfo['PACKSIZE'].astype(int)

# %% [markdown]
# na_variations = ['n/a', 'na', 'not applicable', 'none', 'n.a', 'n.a.', 'n.a..', 'naa', 'naaa', 'n/a?', 'n/a!', 'N/A']
# skuinfo['COLOR'] = skuinfo['COLOR'].astype(str)
# #filtered_rows = skuinfo[skuinfo['COLOR'].str.contains('N/A', case=False).fillna(False)]
# skuinfo['COLOR']=skuinfo['COLOR'].replace(na_variations, 'na', regex=True, inplace=True)
# skuinfo['COLOR'] = skuinfo['COLOR'].str.upper()
#
# skuinfo

# %%
# skuinfo[skuinfo.isna().any(axis=1)]
#mask = df.apply(lambda row: row.astype(str).str.contains(search_string, case=False).any(), axis=1)
# skuinfo.dropna()

# %%
# skuinfo['COLOR'] = skuinfo['COLOR'].str.replace('N/A', '').str.strip()
# skuinfo['COLOR'] = skuinfo['COLOR'].apply(lambda x: None if x.lower() == 'na' else x)

# %%
# skuinfo[skuinfo.isna().any(axis=1)]
#mask = df.apply(lambda row: row.astype(str).str.contains(search_string, case=False).any(), axis=1)
# skuinfo.dropna()

# %% [markdown]
# ###### null_data = skuinfo[skuinfo.isnull().any(axis=1)]
# null_data

# %%
skuinfo2 = pd.read_csv('skuinfoclean.csv')
skuinfo2.drop(['Unnamed: 0'],axis=1,inplace=True)
skuinfo2

# %%
names = ['SKU', 'DEPT','CLASSID','UPC','STYLE','COLOR','SIZE','PACKSIZE','VENDOR','BRAND']

# %%
skuinfo['SIZE'].isnull().sum()

# %%
#so for now, only sizes are missing from the data. the question is whether it matters
skuinfo.isnull().any(axis=1).sum()

# %%
skuinfo.size

# %%
len(skuinfo['SKU'].unique())

# %%
unique_sku_count = skuinfo['SKU'].nunique()
unique_sku_count

# %%
#best selling brands 
brand_counts = skuinfo['BRAND'].value_counts().head(10)
brand_counts

# %%
vendor_counts = skuinfo['VENDOR'].value_counts().head(10)
vendor_counts

# %%
try:
    pd.to_numeric(skuinfo['VENDOR'], errors='raise')
    # If the above line executes without raising an error, it means all values are numeric.
    print(f'All values in column  are numeric.')
except ValueError:
    # If a ValueError is raised, it means there are non-numeric values in the column.
    print(f'Some values in column  are not numeric.')
